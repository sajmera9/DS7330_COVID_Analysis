# %%
import pandas as pd
import numpy as np
from plotnine import ggplot, aes, geom_line

# %%
all_statesdf = pd.read_csv("https://api.covidactnow.org/v2/states.timeseries.csv?apiKey=1540d77cf9a0422b88a2d90e989bbd23")
# Out:
#              date country state  county  fips  lat  long          locationId  \
# 0      2020-03-01      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 1      2020-03-02      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 2      2020-03-03      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 3      2020-03-04      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 4      2020-03-05      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# ...           ...     ...   ...     ...   ...  ...   ...                 ...
# 25981  2021-06-24      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25982  2021-06-25      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25983  2021-06-26      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25984  2021-06-27      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25985  2021-06-28      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
#
#        actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# 0                NaN             NaN  ...                    NaN
# 1                NaN             NaN  ...                    NaN
# 2                NaN             NaN  ...                    NaN
# 3                NaN             NaN  ...                    NaN
# 4                NaN             NaN  ...                    NaN
# ...              ...             ...  ...                    ...
# 25981        61847.0           740.0  ...                   0.92
# 25982        61951.0           740.0  ...                   0.92
# 25983        61951.0           740.0  ...                   0.92
# 25984        61951.0           740.0  ...                   0.91
# 25985            NaN             NaN  ...                    NaN
#
#        metrics.infectionRateCI90  metrics.icuHeadroomRatio  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 25981                       0.22                      0.13
# 25982                       0.23                      0.16
# 25983                       0.24                      0.16
# 25984                       0.24                       NaN
# 25985                        NaN                       NaN
#
#        metrics.icuHeadroomDetails  metrics.icuCapacityRatio  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 25981                         NaN                      0.38
# 25982                         NaN                      0.40
# 25983                         NaN                      0.40
# 25984                         NaN                       NaN
# 25985                         NaN                       NaN
#
#        riskLevels.overall  metrics.vaccinationsInitiatedRatio  \
# 0                       0                                 NaN
# 1                       0                                 NaN
# 2                       0                                 NaN
# 3                       0                                 NaN
# 4                       0                                 NaN
# ...                   ...                                 ...
# 25981                   2                               0.388
# 25982                   2                               0.389
# 25983                   2                               0.390
# 25984                   2                               0.390
# 25985                   2                                 NaN
#
#        metrics.vaccinationsCompletedRatio  actuals.newDeaths  \
# 0                                     NaN                NaN
# 1                                     NaN                NaN
# 2                                     NaN                NaN
# 3                                     NaN                NaN
# 4                                     NaN                NaN
# ...                                   ...                ...
# 25981                               0.338                0.0
# 25982                               0.340                0.0
# 25983                               0.341                0.0
# 25984                               0.341                0.0
# 25985                                 NaN                NaN
#
#        actuals.vaccinesAdministered
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 25981                      415449.0
# 25982                      418095.0
# 25983                      419250.0
# 25984                      419326.0
# 25985                           NaN
#
# [25986 rows x 39 columns]

# %%
all_statesdf.columns
# Out:
# Index(['date', 'country', 'state', 'county', 'fips', 'lat', 'long',
#        'locationId', 'actuals.cases', 'actuals.deaths',
#        'actuals.positiveTests', 'actuals.negativeTests',
#        'actuals.contactTracers', 'actuals.hospitalBeds.capacity',
#        'actuals.hospitalBeds.currentUsageTotal',
#        'actuals.hospitalBeds.currentUsageCovid',
#        'actuals.hospitalBeds.typicalUsageRate', 'actuals.icuBeds.capacity',
#        'actuals.icuBeds.currentUsageTotal',
#        'actuals.icuBeds.currentUsageCovid', 'actuals.icuBeds.typicalUsageRate',
#        'actuals.newCases', 'actuals.vaccinesDistributed',
#        'actuals.vaccinationsInitiated', 'actuals.vaccinationsCompleted',
#        'metrics.testPositivityRatio', 'metrics.testPositivityRatioDetails',
#        'metrics.caseDensity', 'metrics.contactTracerCapacityRatio',
#        'metrics.infectionRate', 'metrics.infectionRateCI90',
#        'metrics.icuHeadroomRatio', 'metrics.icuHeadroomDetails',
#        'metrics.icuCapacityRatio', 'riskLevels.overall',
#        'metrics.vaccinationsInitiatedRatio',
#        'metrics.vaccinationsCompletedRatio', 'actuals.newDeaths',
#        'actuals.vaccinesAdministered'],
#       dtype='object')

# %%
new_df = all_statesdf[["date","state","actuals.hospitalBeds.capacity","actuals.newCases",'actuals.newDeaths',"actuals.vaccinesDistributed","actuals.vaccinationsInitiated","actuals.vaccinationsCompleted",'metrics.vaccinationsInitiatedRatio',
       'metrics.vaccinationsCompletedRatio']]

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25986 entries, 0 to 25985
# Data columns (total 10 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   date                                25986 non-null  object
#  1   state                               25986 non-null  object
#  2   actuals.hospitalBeds.capacity       0 non-null      float64
#  3   actuals.newCases                    25405 non-null  float64
#  4   actuals.newDeaths                   25397 non-null  float64
#  5   actuals.vaccinesDistributed         8230 non-null   float64
#  6   actuals.vaccinationsInitiated       8196 non-null   float64
#  7   actuals.vaccinationsCompleted       8196 non-null   float64
#  8   metrics.vaccinationsInitiatedRatio  8196 non-null   float64
#  9   metrics.vaccinationsCompletedRatio  8196 non-null   float64
# dtypes: float64(8), object(2)
# memory usage: 2.0+ MB
