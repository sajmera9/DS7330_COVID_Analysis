# %%
# !pip install plotnine
# !pip install plotly

# %%
from plotnine.data import economics
from plotnine import ggplot, aes, geom_line
import json
import pandas as pd
import urllib
import plotly.express as px
import requests
from datetime import date

# %%
result = requests.get('https://api.covidactnow.org/v2/states.timeseries.json?apiKey=1540d77cf9a0422b88a2d90e989bbd23')

# %%
result.status_code
# Out:
# 200

# %%
state_json = result.json()

# %%
state_str = json.dumps(state_json,indent=2)

# %%
type(state_json)
# Out:
# list

# %%
state_json[0]
# Out:
# {'fips': '02',
#  'country': 'US',
#  'state': 'AK',
#  'county': None,
#  'level': 'state',
#  'lat': None,
#  'locationId': 'iso1:us#iso2:us-ak',
#  'long': None,
#  'population': 731545,
#  'metrics': {'testPositivityRatio': 0.008,
#   'testPositivityRatioDetails': {'source': 'other'},
#   'caseDensity': 3.5,
#   'contactTracerCapacityRatio': 1.84,
#   'infectionRate': 0.88,
#   'infectionRateCI90': 0.26,
#   'icuHeadroomRatio': 0.11,
#   'icuHeadroomDetails': {'currentIcuCovid': 5,
#    'currentIcuCovidMethod': 'actual',
#    'currentIcuNonCovid': 85,
#    'currentIcuNonCovidMethod': 'actual'},
#   'icuCapacityRatio': 0.69,
#   'vaccinationsInitiatedRatio': 0.475,
#   'vaccinationsCompletedRatio': 0.413},
#  'riskLevels': {'overall': 1,
#   'testPositivityRatio': 0,
#   'caseDensity': 1,
#   'contactTracerCapacityRatio': 0,
#   'infectionRate': 0,
#   'icuHeadroomRatio': 0,
#   'icuCapacityRatio': 0},
#  'actuals': {'cases': 70183,
#   'deaths': 356,
#   'positiveTests': 112922,
#   'negativeTests': 2374884,
#   'contactTracers': 235,
#   'hospitalBeds': {'capacity': 1853,
#    'currentUsageTotal': 1026,
#    'currentUsageCovid': 18,
#    'typicalUsageRate': 0.58},
#   'icuBeds': {'capacity': 130,
#    'currentUsageTotal': 90,
#    'currentUsageCovid': 5,
#    'typicalUsageRate': 0.676923076923},
#   'newCases': 51,
#   'newDeaths': 0,
#   'vaccinesDistributed': 822845,
#   'vaccinationsInitiated': 347501,
#   'vaccinationsCompleted': 301947,
#   'vaccinesAdministered': 634868,
#   'vaccinesAdministeredDemographics': None,
#   'vaccinationsInitiatedDemographics': None},
#  'annotations': {'cases': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'deaths': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'positiveTests': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'negativeTests': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'contactTracers': {'sources': [{'type': 'TestAndTrace',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'hospitalBeds': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'icuBeds': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'newCases': None,
#   'newDeaths': None,
#   'vaccinesDistributed': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsInitiated': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsCompleted': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinesAdministered': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'testPositivityRatio': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'caseDensity': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'contactTracerCapacityRatio': {'sources': [{'type': 'TestAndTrace',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'infectionRate': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'infectionRateCI90': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'icuHeadroomRatio': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'icuCapacityRatio': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'vaccinationsInitiatedRatio': None,
#   'vaccinationsCompletedRatio': None},
#  'lastUpdatedDate': '2021-06-17',
#  'url': 'https://covidactnow.org/us/alaska-ak',
#  'metricsTimeseries': [{'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-01'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-02'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-03'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-04'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-05'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-06'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-07'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-08'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-09'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-10'},
#   {'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-11'},
#   {'testPositivityRatio': 0.0,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-12'},
#   {'testPositivityRatio': 0.011,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.41,
#    'infectionRateCI90': 0.96,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-13'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.42,
#    'infectionRateCI90': 0.88,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-14'},
#   {'testPositivityRatio': 0.014,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.43,
#    'infectionRateCI90': 0.82,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-15'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 0.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.43,
#    'infectionRateCI90': 0.81,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-16'},
#   {'testPositivityRatio': 0.014,
#    'caseDensity': 0.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.44,
#    'infectionRateCI90': 0.77,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-17'},
#   {'testPositivityRatio': 0.017,
#    'caseDensity': 0.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.44,
#    'infectionRateCI90': 0.75,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-18'},
#   {'testPositivityRatio': 0.017,
#    'caseDensity': 0.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.43,
#    'infectionRateCI90': 0.72,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-19'},
#   {'testPositivityRatio': 0.021,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.42,
#    'infectionRateCI90': 0.69,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-20'},
#   {'testPositivityRatio': 0.023,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.41,
#    'infectionRateCI90': 0.64,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-21'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.39,
#    'infectionRateCI90': 0.62,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-22'},
#   {'testPositivityRatio': 0.029,
#    'caseDensity': 0.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.36,
#    'infectionRateCI90': 0.59,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-23'},
#   {'testPositivityRatio': 0.029,
#    'caseDensity': 0.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.34,
#    'infectionRateCI90': 0.56,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-24'},
#   {'testPositivityRatio': 0.029,
#    'caseDensity': 1.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.3,
#    'infectionRateCI90': 0.54,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-25'},
#   {'testPositivityRatio': 0.032,
#    'caseDensity': 1.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.27,
#    'infectionRateCI90': 0.51,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-26'},
#   {'testPositivityRatio': 0.031,
#    'caseDensity': 1.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.24,
#    'infectionRateCI90': 0.49,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-27'},
#   {'testPositivityRatio': 0.029,
#    'caseDensity': 1.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.2,
#    'infectionRateCI90': 0.47,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-28'},
#   {'testPositivityRatio': 0.027,
#    'caseDensity': 1.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-29'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 1.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-30'},
#   {'testPositivityRatio': 0.03,
#    'caseDensity': 1.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.44,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-31'},
#   {'testPositivityRatio': 0.027,
#    'caseDensity': 1.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.05,
#    'infectionRateCI90': 0.45,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-01'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 1.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.44,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-02'},
#   {'testPositivityRatio': 0.03,
#    'caseDensity': 1.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.98,
#    'infectionRateCI90': 0.45,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-03'},
#   {'testPositivityRatio': 0.032,
#    'caseDensity': 1.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.95,
#    'infectionRateCI90': 0.45,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-04'},
#   {'testPositivityRatio': 0.033,
#    'caseDensity': 1.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.93,
#    'infectionRateCI90': 0.45,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-05'},
#   {'testPositivityRatio': 0.033,
#    'caseDensity': 1.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.9,
#    'infectionRateCI90': 0.45,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-06'},
#   {'testPositivityRatio': 0.03,
#    'caseDensity': 1.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.88,
#    'infectionRateCI90': 0.45,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-07'},
#   {'testPositivityRatio': 0.034,
#    'caseDensity': 1.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.85,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-08'},
#   {'testPositivityRatio': 0.031,
#    'caseDensity': 1.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.83,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-09'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 1.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.81,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-10'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 1.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.79,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-11'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 1.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.77,
#    'infectionRateCI90': 0.47,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-12'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 1.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.75,
#    'infectionRateCI90': 0.47,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-13'},
#   {'testPositivityRatio': 0.022,
#    'caseDensity': 1.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.73,
#    'infectionRateCI90': 0.47,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-14'},
#   {'testPositivityRatio': 0.021,
#    'caseDensity': 1.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.71,
#    'infectionRateCI90': 0.48,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-15'},
#   {'testPositivityRatio': 0.02,
#    'caseDensity': 1.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.69,
#    'infectionRateCI90': 0.49,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-16'},
#   {'testPositivityRatio': 0.02,
#    'caseDensity': 1.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.68,
#    'infectionRateCI90': 0.49,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-17'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 1.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.66,
#    'infectionRateCI90': 0.51,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-18'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 0.9,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.65,
#    'infectionRateCI90': 0.53,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-19'},
#   {'testPositivityRatio': 0.014,
#    'caseDensity': 0.9,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.64,
#    'infectionRateCI90': 0.54,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-20'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 0.9,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.63,
#    'infectionRateCI90': 0.56,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-21'},
#   {'testPositivityRatio': 0.01,
#    'caseDensity': 0.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.63,
#    'infectionRateCI90': 0.58,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-22'},
#   {'testPositivityRatio': 0.008,
#    'caseDensity': 0.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.63,
#    'infectionRateCI90': 0.6,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-23'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 0.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.63,
#    'infectionRateCI90': 0.63,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-24'},
#   {'testPositivityRatio': 0.01,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.63,
#    'infectionRateCI90': 0.65,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-25'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.64,
#    'infectionRateCI90': 0.67,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-26'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.64,
#    'infectionRateCI90': 0.69,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-27'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.65,
#    'infectionRateCI90': 0.71,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-28'},
#   {'testPositivityRatio': 0.01,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.66,
#    'infectionRateCI90': 0.72,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-29'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.67,
#    'infectionRateCI90': 0.73,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-30'},
#   {'testPositivityRatio': 0.008,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.68,
#    'infectionRateCI90': 0.73,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-01'},
#   {'testPositivityRatio': 0.007,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.69,
#    'infectionRateCI90': 0.74,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-02'},
#   {'testPositivityRatio': 0.006,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.71,
#    'infectionRateCI90': 0.75,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-03'},
#   {'testPositivityRatio': 0.005,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.72,
#    'infectionRateCI90': 0.76,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-04'},
#   {'testPositivityRatio': 0.004,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.73,
#    'infectionRateCI90': 0.77,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-05'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.74,
#    'infectionRateCI90': 0.77,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-06'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.76,
#    'infectionRateCI90': 0.78,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-07'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.77,
#    'infectionRateCI90': 0.78,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-08'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.78,
#    'infectionRateCI90': 0.79,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-09'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.8,
#    'infectionRateCI90': 0.8,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-10'},
#   {'testPositivityRatio': 0.002,
#    'caseDensity': 0.2,
#    'contactTracerCapacityRatio': 16.33,
#    'infectionRate': 0.82,
#    'infectionRateCI90': 0.8,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-11'},
#   {'testPositivityRatio': 0.002,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 14.0,
#    'infectionRate': 0.84,
#    'infectionRateCI90': 0.81,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-12'},
#   {'testPositivityRatio': 0.002,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 15.08,
#    'infectionRate': 0.86,
#    'infectionRateCI90': 0.81,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-13'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 14.0,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.81,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-14'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.2,
#    'contactTracerCapacityRatio': 16.33,
#    'infectionRate': 0.92,
#    'infectionRateCI90': 0.8,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-15'},
#   {'testPositivityRatio': 0.004,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 13.07,
#    'infectionRate': 0.96,
#    'infectionRateCI90': 0.79,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-16'},
#   {'testPositivityRatio': 0.004,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': 10.89,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.78,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-17'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': 10.32,
#    'infectionRate': 1.03,
#    'infectionRateCI90': 0.76,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-18'},
#   {'testPositivityRatio': 0.004,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 12.69,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.77,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-19'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': 10.68,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.76,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-20'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 13.53,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.74,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-21'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 12.69,
#    'infectionRate': 1.21,
#    'infectionRateCI90': 0.75,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-22'},
#   {'testPositivityRatio': 0.002,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 11.94,
#    'infectionRate': 1.25,
#    'infectionRateCI90': 0.73,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-23'},
#   {'testPositivityRatio': 0.002,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 15.62,
#    'infectionRate': 1.29,
#    'infectionRateCI90': 0.72,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-24'},
#   {'testPositivityRatio': 0.002,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 15.62,
#    'infectionRate': 1.32,
#    'infectionRateCI90': 0.7,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-25'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 11.94,
#    'infectionRate': 1.35,
#    'infectionRateCI90': 0.69,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-26'},
#   {'testPositivityRatio': 0.003,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': 13.53,
#    'infectionRate': 1.37,
#    'infectionRateCI90': 0.65,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-27'},
#   {'testPositivityRatio': 0.004,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': 7.25,
#    'infectionRate': 1.38,
#    'infectionRateCI90': 0.61,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-28'},
#   {'testPositivityRatio': 0.006,
#    'caseDensity': 0.6,
#    'contactTracerCapacityRatio': 6.34,
#    'infectionRate': 1.39,
#    'infectionRateCI90': 0.56,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-29'},
#   {'testPositivityRatio': 0.006,
#    'caseDensity': 0.6,
#    'contactTracerCapacityRatio': 6.34,
#    'infectionRate': 1.38,
#    'infectionRateCI90': 0.54,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-30'},
#   {'testPositivityRatio': 0.007,
#    'caseDensity': 1.2,
#    'contactTracerCapacityRatio': 3.38,
#    'infectionRate': 1.37,
#    'infectionRateCI90': 0.49,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-31'},
#   {'testPositivityRatio': 0.008,
#    'caseDensity': 1.2,
#    'contactTracerCapacityRatio': 3.17,
#    'infectionRate': 1.36,
#    'infectionRateCI90': 0.46,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-01'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 1.6,
#    'contactTracerCapacityRatio': 2.16,
#    'infectionRate': 1.34,
#    'infectionRateCI90': 0.43,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-02'},
#   {'testPositivityRatio': 0.01,
#    'caseDensity': 1.9,
#    'contactTracerCapacityRatio': 1.77,
#    'infectionRate': 1.31,
#    'infectionRateCI90': 0.41,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-03'},
#   {'testPositivityRatio': 0.01,
#    'caseDensity': 2.2,
#    'contactTracerCapacityRatio': 1.62,
#    'infectionRate': 1.28,
#    'infectionRateCI90': 0.39,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-04'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 2.5,
#    'contactTracerCapacityRatio': 1.41,
#    'infectionRate': 1.25,
#    'infectionRateCI90': 0.37,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-05'},
#   {'testPositivityRatio': 0.009,
#    'caseDensity': 2.7,
#    'contactTracerCapacityRatio': 1.32,
#    'infectionRate': 1.22,
#    'infectionRateCI90': 0.35,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-06'},
#   {'testPositivityRatio': 0.008,
#    'caseDensity': 2.3,
#    'contactTracerCapacityRatio': 1.53,
#    'infectionRate': 1.19,
#    'infectionRateCI90': 0.34,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-07'},
#   {'testPositivityRatio': 0.007,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': 1.39,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.34,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-08'},
#   {'testPositivityRatio': 0.007,
#    'caseDensity': 2.4,
#    'contactTracerCapacityRatio': 1.48,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.34,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-09'},
#   {'testPositivityRatio': 0.01,
#    'caseDensity': 2.5,
#    'contactTracerCapacityRatio': 1.44,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.33,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-10'},
#   {'testPositivityRatio': 0.011,
#    'caseDensity': 2.4,
#    'contactTracerCapacityRatio': 1.43,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.33,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-11'},
#   {'testPositivityRatio': 0.015,
#    'caseDensity': 2.4,
#    'contactTracerCapacityRatio': 1.45,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-12'},
#   {'testPositivityRatio': 0.015,
#    'caseDensity': 2.8,
#    'contactTracerCapacityRatio': 1.24,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.31,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-13'},
#   {'testPositivityRatio': 0.015,
#    'caseDensity': 2.9,
#    'contactTracerCapacityRatio': 1.22,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.31,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-14'},
#   {'testPositivityRatio': 0.015,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': 1.36,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.31,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-15'},
#   {'testPositivityRatio': 0.014,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': 1.36,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-16'},
#   {'testPositivityRatio': 0.013,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': 1.33,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-17'},
#   {'testPositivityRatio': 0.014,
#    'caseDensity': 2.5,
#    'contactTracerCapacityRatio': 1.42,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-18'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': 1.38,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-19'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 2.4,
#    'contactTracerCapacityRatio': 1.49,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.31,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-20'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 2.4,
#    'contactTracerCapacityRatio': 1.47,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.31,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-21'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': 1.4,
#    'infectionRate': 1.17,
#    'infectionRateCI90': 0.3,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-22'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 3.0,
#    'contactTracerCapacityRatio': 1.26,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.3,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-23'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 2.9,
#    'contactTracerCapacityRatio': 1.3,
#    'infectionRate': 1.19,
#    'infectionRateCI90': 0.3,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-24'},
#   {'testPositivityRatio': 0.011,
#    'caseDensity': 3.4,
#    'contactTracerCapacityRatio': 1.11,
#    'infectionRate': 1.2,
#    'infectionRateCI90': 0.3,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-25'},
#   {'testPositivityRatio': 0.011,
#    'caseDensity': 3.5,
#    'contactTracerCapacityRatio': 1.08,
#    'infectionRate': 1.21,
#    'infectionRateCI90': 0.29,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-26'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 3.6,
#    'contactTracerCapacityRatio': 1.07,
#    'infectionRate': 1.22,
#    'infectionRateCI90': 0.27,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-27'},
#   {'testPositivityRatio': 0.012,
#    'caseDensity': 3.9,
#    'contactTracerCapacityRatio': 0.97,
#    'infectionRate': 1.22,
#    'infectionRateCI90': 0.25,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-28'},
#   {'testPositivityRatio': 0.013,
#    'caseDensity': 4.2,
#    'contactTracerCapacityRatio': 0.9,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.25,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-29'},
#   {'testPositivityRatio': 0.015,
#    'caseDensity': 4.4,
#    'contactTracerCapacityRatio': 0.86,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.23,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-30'},
#   {'testPositivityRatio': 0.015,
#    'caseDensity': 4.8,
#    'contactTracerCapacityRatio': 0.78,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.23,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-01'},
#   {'testPositivityRatio': 0.017,
#    'caseDensity': 4.9,
#    'contactTracerCapacityRatio': 0.77,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.22,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-02'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 5.5,
#    'contactTracerCapacityRatio': 0.69,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.22,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-03'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 6.1,
#    'contactTracerCapacityRatio': 0.62,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.22,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-04'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 6.1,
#    'contactTracerCapacityRatio': 0.63,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.2,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-05'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 6.2,
#    'contactTracerCapacityRatio': 0.62,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.2,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-06'},
#   {'testPositivityRatio': 0.017,
#    'caseDensity': 5.7,
#    'contactTracerCapacityRatio': 0.69,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.2,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-07'},
#   {'testPositivityRatio': 0.016,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': 0.7,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.2,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-08'},
#   {'testPositivityRatio': 0.018,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': 0.71,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.19,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-09'},
#   {'testPositivityRatio': 0.02,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': 0.71,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.19,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-10'},
#   {'testPositivityRatio': 0.022,
#    'caseDensity': 6.2,
#    'contactTracerCapacityRatio': 0.66,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.19,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-11'},
#   {'testPositivityRatio': 0.022,
#    'caseDensity': 7.8,
#    'contactTracerCapacityRatio': 0.52,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.19,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-12'},
#   {'testPositivityRatio': 0.021,
#    'caseDensity': 8.6,
#    'contactTracerCapacityRatio': 0.48,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.18,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-13'},
#   {'testPositivityRatio': 0.021,
#    'caseDensity': 9.3,
#    'contactTracerCapacityRatio': 0.44,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.17,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-14'},
#   {'testPositivityRatio': 0.022,
#    'caseDensity': 9.5,
#    'contactTracerCapacityRatio': 0.43,
#    'infectionRate': 1.23,
#    'infectionRateCI90': 0.17,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-15'},
#   {'testPositivityRatio': 0.021,
#    'caseDensity': 10.0,
#    'contactTracerCapacityRatio': 0.41,
#    'infectionRate': 1.22,
#    'infectionRateCI90': 0.17,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-16'},
#   {'testPositivityRatio': 0.019,
#    'caseDensity': 9.8,
#    'contactTracerCapacityRatio': 0.42,
#    'infectionRate': 1.22,
#    'infectionRateCI90': 0.17,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-17'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 9.8,
#    'contactTracerCapacityRatio': 0.42,
#    'infectionRate': 1.21,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-18'},
#   {'testPositivityRatio': 0.026,
#    'caseDensity': 9.8,
#    'contactTracerCapacityRatio': 0.42,
#    'infectionRate': 1.2,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-19'},
#   {'testPositivityRatio': 0.026,
#    'caseDensity': 11.1,
#    'contactTracerCapacityRatio': 0.37,
#    'infectionRate': 1.19,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-20'},
#   {'testPositivityRatio': 0.03,
#    'caseDensity': 12.2,
#    'contactTracerCapacityRatio': 0.38,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-21'},
#   {'testPositivityRatio': 0.033,
#    'caseDensity': 12.9,
#    'contactTracerCapacityRatio': 0.37,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-22'},
#   {'testPositivityRatio': 0.038,
#    'caseDensity': 12.7,
#    'contactTracerCapacityRatio': 0.37,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-23'},
#   {'testPositivityRatio': 0.041,
#    'caseDensity': 12.9,
#    'contactTracerCapacityRatio': 0.36,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-24'},
#   {'testPositivityRatio': 0.04,
#    'caseDensity': 13.8,
#    'contactTracerCapacityRatio': 0.34,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-25'},
#   {'testPositivityRatio': 0.039,
#    'caseDensity': 16.1,
#    'contactTracerCapacityRatio': 0.29,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-26'},
#   {'testPositivityRatio': 0.04,
#    'caseDensity': 15.5,
#    'contactTracerCapacityRatio': 0.3,
#    'infectionRate': 1.06,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-27'},
#   {'testPositivityRatio': 0.039,
#    'caseDensity': 16.1,
#    'contactTracerCapacityRatio': 0.29,
#    'infectionRate': 1.04,
#    'infectionRateCI90': 0.13,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-28'},
#   {'testPositivityRatio': 0.041,
#    'caseDensity': 16.1,
#    'contactTracerCapacityRatio': 0.29,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.13,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-29'},
#   {'testPositivityRatio': 0.037,
#    'caseDensity': 17.1,
#    'contactTracerCapacityRatio': 0.28,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.12,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-30'},
#   {'testPositivityRatio': 0.037,
#    'caseDensity': 18.1,
#    'contactTracerCapacityRatio': 0.26,
#    'infectionRate': 0.97,
#    'infectionRateCI90': 0.12,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-31'},
#   {'testPositivityRatio': 0.036,
#    'caseDensity': 18.7,
#    'contactTracerCapacityRatio': 0.25,
#    'infectionRate': 0.95,
#    'infectionRateCI90': 0.12,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-01'},
#   {'testPositivityRatio': 0.035,
#    'caseDensity': 17.2,
#    'contactTracerCapacityRatio': 0.27,
#    'infectionRate': 0.93,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-02'},
#   {'testPositivityRatio': 0.035,
#    'caseDensity': 16.8,
#    'contactTracerCapacityRatio': 0.28,
#    'infectionRate': 0.92,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-03'},
#   {'testPositivityRatio': 0.033,
#    'caseDensity': 15.1,
#    'contactTracerCapacityRatio': 0.31,
#    'infectionRate': 0.91,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-04'},
#   {'testPositivityRatio': 0.031,
#    'caseDensity': 14.5,
#    'contactTracerCapacityRatio': 0.32,
#    'infectionRate': 0.9,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-05'},
#   {'testPositivityRatio': 0.03,
#    'caseDensity': 13.0,
#    'contactTracerCapacityRatio': 0.36,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-06'},
#   {'testPositivityRatio': 0.029,
#    'caseDensity': 11.9,
#    'contactTracerCapacityRatio': 0.39,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.12,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-07'},
#   {'testPositivityRatio': 0.027,
#    'caseDensity': 10.7,
#    'contactTracerCapacityRatio': 0.44,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.13,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-08'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 9.5,
#    'contactTracerCapacityRatio': 0.49,
#    'infectionRate': 0.9,
#    'infectionRateCI90': 0.13,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-09'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 9.3,
#    'contactTracerCapacityRatio': 0.51,
#    'infectionRate': 0.91,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-10'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 9.1,
#    'contactTracerCapacityRatio': 0.57,
#    'infectionRate': 0.91,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-11'},
#   {'testPositivityRatio': 0.026,
#    'caseDensity': 9.2,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 0.92,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-12'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 10.3,
#    'contactTracerCapacityRatio': 0.62,
#    'infectionRate': 0.93,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-13'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 11.3,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 0.94,
#    'infectionRateCI90': 0.17,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-14'},
#   {'testPositivityRatio': 0.026,
#    'caseDensity': 11.3,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 0.95,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-15'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 11.5,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 0.96,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-16'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 11.2,
#    'contactTracerCapacityRatio': 0.57,
#    'infectionRate': 0.97,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-17'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 11.5,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 0.97,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-18'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 11.6,
#    'contactTracerCapacityRatio': 0.55,
#    'infectionRate': 0.98,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-19'},
#   {'testPositivityRatio': 0.023,
#    'caseDensity': 11.4,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 0.98,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-20'},
#   {'testPositivityRatio': 0.023,
#    'caseDensity': 10.4,
#    'contactTracerCapacityRatio': 0.61,
#    'infectionRate': 0.98,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-21'},
#   {'testPositivityRatio': 0.024,
#    'caseDensity': 10.5,
#    'contactTracerCapacityRatio': 0.61,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-22'},
#   {'testPositivityRatio': 0.023,
#    'caseDensity': 9.7,
#    'contactTracerCapacityRatio': 0.66,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-23'},
#   {'testPositivityRatio': 0.023,
#    'caseDensity': 10.1,
#    'contactTracerCapacityRatio': 0.63,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-24'},
#   {'testPositivityRatio': 0.023,
#    'caseDensity': None,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-25'},
#   {'testPositivityRatio': 0.025,
#    'caseDensity': 9.8,
#    'contactTracerCapacityRatio': 0.65,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-26'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 9.7,
#    'contactTracerCapacityRatio': 0.66,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-27'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 10.9,
#    'contactTracerCapacityRatio': 0.59,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-28'},
#   {'testPositivityRatio': 0.028,
#    'caseDensity': 11.3,
#    'contactTracerCapacityRatio': 0.56,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-29'},
#   {'testPositivityRatio': 0.027,
#    'caseDensity': 11.0,
#    'contactTracerCapacityRatio': 0.58,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.15,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08
#   {'overall': 1, 'date': '2021-05-29'},
#   {'overall': 1, 'date': '2021-05-30'},
#   {'overall': 1, 'date': '2021-05-31'},
#   {'overall': 1, 'date': '2021-06-01'},
#   {'overall': 1, 'date': '2021-06-02'},
#   {'overall': 1, 'date': '2021-06-03'},
#   {'overall': 1, 'date': '2021-06-04'},
#   {'overall': 1, 'date': '2021-06-05'},
#   {'overall': 1, 'date': '2021-06-06'},
#   {'overall': 1, 'date': '2021-06-07'},
#   {'overall': 1, 'date': '2021-06-08'},
#   {'overall': 1, 'date': '2021-06-09'},
#   {'overall': 1, 'date': '2021-06-10'},
#   {'overall': 1, 'date': '2021-06-11'},
#   {'overall': 1, 'date': '2021-06-12'},
#   {'overall': 1, 'date': '2021-06-13'},
#   {'overall': 1, 'date': '2021-06-14'},
#   {'overall': 1, 'date': '2021-06-15'},
#   {'overall': 1, 'date': '2021-06-16'},
#   {'overall': 1, 'date': '2021-06-17'}]}

# %%
state_json[1]
# Out:
# {'fips': '01',
#  'country': 'US',
#  'state': 'AL',
#  'county': None,
#  'level': 'state',
#  'lat': None,
#  'locationId': 'iso1:us#iso2:us-al',
#  'long': None,
#  'population': 4903185,
#  'metrics': {'testPositivityRatio': 0.041,
#   'testPositivityRatioDetails': {'source': 'other'},
#   'caseDensity': 4.3,
#   'contactTracerCapacityRatio': 0.38,
#   'infectionRate': 0.94,
#   'infectionRateCI90': 0.1,
#   'icuHeadroomRatio': 0.17,
#   'icuHeadroomDetails': {'currentIcuCovid': 73,
#    'currentIcuCovidMethod': 'actual',
#    'currentIcuNonCovid': 1214,
#    'currentIcuNonCovidMethod': 'actual'},
#   'icuCapacityRatio': 0.78,
#   'vaccinationsInitiatedRatio': 0.372,
#   'vaccinationsCompletedRatio': 0.308},
#  'riskLevels': {'overall': 1,
#   'testPositivityRatio': 1,
#   'caseDensity': 1,
#   'contactTracerCapacityRatio': 1,
#   'infectionRate': 1,
#   'icuHeadroomRatio': 0,
#   'icuCapacityRatio': 1},
#  'actuals': {'cases': 545758,
#   'deaths': 11288,
#   'positiveTests': 545499,
#   'negativeTests': 4122989,
#   'contactTracers': 404,
#   'hospitalBeds': {'capacity': 19167,
#    'currentUsageTotal': 11595,
#    'currentUsageCovid': 280,
#    'typicalUsageRate': 0.6},
#   'icuBeds': {'capacity': 1644,
#    'currentUsageTotal': 1287,
#    'currentUsageCovid': 73,
#    'typicalUsageRate': 0.7},
#   'newCases': 160,
#   'newDeaths': 7,
#   'vaccinesDistributed': 4692070,
#   'vaccinationsInitiated': 1822146,
#   'vaccinationsCompleted': 1508504,
#   'vaccinesAdministered': 3141802,
#   'vaccinesAdministeredDemographics': None,
#   'vaccinationsInitiatedDemographics': None},
#  'annotations': {'cases': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'deaths': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'positiveTests': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'negativeTests': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'contactTracers': {'sources': [{'type': 'TestAndTrace',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'hospitalBeds': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'icuBeds': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'newCases': {'sources': [],
#    'anomalies': [{'date': '2020-03-25',
#      'type': 'zscore_outlier',
#      'original_observation': 144.0},
#     {'date': '2021-03-15',
#      'type': 'zscore_outlier',
#      'original_observation': 4556.0},
#     {'date': '2021-04-13',
#      'type': 'zscore_outlier',
#      'original_observation': 1432.0}]},
#   'newDeaths': None,
#   'vaccinesDistributed': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsInitiated': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinationsCompleted': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'vaccinesAdministered': {'sources': [{'type': 'other',
#      'url': 'https://covid.cdc.gov/covid-data-tracker/#vaccinations',
#      'name': 'Centers for Disease Control and Prevention'}],
#    'anomalies': []},
#   'testPositivityRatio': {'sources': [{'type': 'HHSTesting',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'caseDensity': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'contactTracerCapacityRatio': {'sources': [{'type': 'TestAndTrace',
#      'url': None,
#      'name': None}],
#    'anomalies': []},
#   'infectionRate': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'infectionRateCI90': {'sources': [{'type': 'NYTimes',
#      'url': 'https://github.com/nytimes/covid-19-data',
#      'name': 'The New York Times'}],
#    'anomalies': []},
#   'icuHeadroomRatio': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'icuCapacityRatio': {'sources': [{'type': 'other',
#      'url': 'https://healthdata.gov/Hospital/COVID-19-Reported-Patient-Impact-and-Hospital-Capa/g62h-syeh',
#      'name': 'Department of Health and Human Services'}],
#    'anomalies': []},
#   'vaccinationsInitiatedRatio': None,
#   'vaccinationsCompletedRatio': None},
#  'lastUpdatedDate': '2021-06-17',
#  'url': 'https://covidactnow.org/us/alabama-al',
#  'metricsTimeseries': [{'testPositivityRatio': None,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-01'},
#   {'testPositivityRatio': 0.077,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-02'},
#   {'testPositivityRatio': 0.083,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-03'},
#   {'testPositivityRatio': 0.08,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-04'},
#   {'testPositivityRatio': 0.092,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-05'},
#   {'testPositivityRatio': 0.102,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-06'},
#   {'testPositivityRatio': 0.107,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-07'},
#   {'testPositivityRatio': 0.12,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-08'},
#   {'testPositivityRatio': 0.122,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-09'},
#   {'testPositivityRatio': 0.123,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-10'},
#   {'testPositivityRatio': 0.159,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-11'},
#   {'testPositivityRatio': 0.159,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-12'},
#   {'testPositivityRatio': 0.122,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': None,
#    'infectionRateCI90': None,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-13'},
#   {'testPositivityRatio': 0.088,
#    'caseDensity': 0.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.53,
#    'infectionRateCI90': 0.92,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-14'},
#   {'testPositivityRatio': 0.081,
#    'caseDensity': 0.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.55,
#    'infectionRateCI90': 0.42,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-15'},
#   {'testPositivityRatio': 0.079,
#    'caseDensity': 0.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.57,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-16'},
#   {'testPositivityRatio': 0.071,
#    'caseDensity': 0.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.58,
#    'infectionRateCI90': 0.36,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-17'},
#   {'testPositivityRatio': 0.053,
#    'caseDensity': 0.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.6,
#    'infectionRateCI90': 0.34,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-18'},
#   {'testPositivityRatio': 0.052,
#    'caseDensity': 0.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.61,
#    'infectionRateCI90': 0.32,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-19'},
#   {'testPositivityRatio': 0.059,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.62,
#    'infectionRateCI90': 0.31,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-20'},
#   {'testPositivityRatio': 0.055,
#    'caseDensity': 0.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.62,
#    'infectionRateCI90': 0.29,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-21'},
#   {'testPositivityRatio': 0.059,
#    'caseDensity': 0.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.62,
#    'infectionRateCI90': 0.25,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-22'},
#   {'testPositivityRatio': 0.077,
#    'caseDensity': 0.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.62,
#    'infectionRateCI90': 0.24,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-23'},
#   {'testPositivityRatio': 0.082,
#    'caseDensity': 0.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.61,
#    'infectionRateCI90': 0.23,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-24'},
#   {'testPositivityRatio': 0.089,
#    'caseDensity': None,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.6,
#    'infectionRateCI90': 0.24,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-25'},
#   {'testPositivityRatio': 0.093,
#    'caseDensity': 1.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.59,
#    'infectionRateCI90': 0.2,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-26'},
#   {'testPositivityRatio': 0.096,
#    'caseDensity': 1.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.58,
#    'infectionRateCI90': 0.18,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-27'},
#   {'testPositivityRatio': 0.105,
#    'caseDensity': 1.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.56,
#    'infectionRateCI90': 0.16,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-28'},
#   {'testPositivityRatio': 0.103,
#    'caseDensity': 1.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.53,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-29'},
#   {'testPositivityRatio': 0.102,
#    'caseDensity': 2.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.5,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-30'},
#   {'testPositivityRatio': 0.107,
#    'caseDensity': 2.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.47,
#    'infectionRateCI90': 0.14,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-03-31'},
#   {'testPositivityRatio': 0.114,
#    'caseDensity': 2.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.44,
#    'infectionRateCI90': 0.13,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-01'},
#   {'testPositivityRatio': 0.125,
#    'caseDensity': 2.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.41,
#    'infectionRateCI90': 0.12,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-02'},
#   {'testPositivityRatio': 0.134,
#    'caseDensity': 2.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.38,
#    'infectionRateCI90': 0.13,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-03'},
#   {'testPositivityRatio': 0.138,
#    'caseDensity': 2.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.35,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-04'},
#   {'testPositivityRatio': 0.141,
#    'caseDensity': 2.9,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.31,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-05'},
#   {'testPositivityRatio': 0.14,
#    'caseDensity': 3.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.28,
#    'infectionRateCI90': 0.12,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-06'},
#   {'testPositivityRatio': 0.146,
#    'caseDensity': 3.5,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.25,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-07'},
#   {'testPositivityRatio': 0.149,
#    'caseDensity': 4.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.21,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-08'},
#   {'testPositivityRatio': 0.143,
#    'caseDensity': 4.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-09'},
#   {'testPositivityRatio': 0.136,
#    'caseDensity': 4.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-10'},
#   {'testPositivityRatio': 0.131,
#    'caseDensity': 4.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-11'},
#   {'testPositivityRatio': 0.127,
#    'caseDensity': 5.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-12'},
#   {'testPositivityRatio': 0.127,
#    'caseDensity': 5.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-13'},
#   {'testPositivityRatio': 0.123,
#    'caseDensity': 5.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.06,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-14'},
#   {'testPositivityRatio': 0.117,
#    'caseDensity': 5.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.04,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-15'},
#   {'testPositivityRatio': 0.114,
#    'caseDensity': 4.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.02,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-16'},
#   {'testPositivityRatio': 0.103,
#    'caseDensity': 4.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-17'},
#   {'testPositivityRatio': 0.101,
#    'caseDensity': 4.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-18'},
#   {'testPositivityRatio': 0.106,
#    'caseDensity': 3.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-19'},
#   {'testPositivityRatio': 0.106,
#    'caseDensity': 3.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-20'},
#   {'testPositivityRatio': 0.106,
#    'caseDensity': 4.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-21'},
#   {'testPositivityRatio': 0.107,
#    'caseDensity': 4.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-22'},
#   {'testPositivityRatio': 0.105,
#    'caseDensity': 4.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-23'},
#   {'testPositivityRatio': 0.119,
#    'caseDensity': 4.2,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-24'},
#   {'testPositivityRatio': 0.12,
#    'caseDensity': 4.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.02,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-25'},
#   {'testPositivityRatio': 0.117,
#    'caseDensity': 4.4,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.03,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-26'},
#   {'testPositivityRatio': 0.118,
#    'caseDensity': 4.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.05,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-27'},
#   {'testPositivityRatio': 0.092,
#    'caseDensity': 4.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.06,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-28'},
#   {'testPositivityRatio': 0.093,
#    'caseDensity': 3.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.07,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-29'},
#   {'testPositivityRatio': 0.096,
#    'caseDensity': 3.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.11,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-04-30'},
#   {'testPositivityRatio': 0.094,
#    'caseDensity': 3.7,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-01'},
#   {'testPositivityRatio': 0.097,
#    'caseDensity': 4.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-02'},
#   {'testPositivityRatio': 0.096,
#    'caseDensity': 4.3,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-03'},
#   {'testPositivityRatio': 0.095,
#    'caseDensity': 4.6,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-04'},
#   {'testPositivityRatio': 0.112,
#    'caseDensity': 4.9,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-05'},
#   {'testPositivityRatio': 0.108,
#    'caseDensity': 5.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-06'},
#   {'testPositivityRatio': 0.104,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-07'},
#   {'testPositivityRatio': 0.103,
#    'caseDensity': 6.1,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-08'},
#   {'testPositivityRatio': 0.098,
#    'caseDensity': 6.0,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-09'},
#   {'testPositivityRatio': 0.096,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': None,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-10'},
#   {'testPositivityRatio': 0.095,
#    'caseDensity': 6.0,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-11'},
#   {'testPositivityRatio': 0.096,
#    'caseDensity': 5.9,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-12'},
#   {'testPositivityRatio': 0.095,
#    'caseDensity': 5.9,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-13'},
#   {'testPositivityRatio': 0.095,
#    'caseDensity': 6.0,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-14'},
#   {'testPositivityRatio': 0.099,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-15'},
#   {'testPositivityRatio': 0.102,
#    'caseDensity': 5.8,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-16'},
#   {'testPositivityRatio': 0.102,
#    'caseDensity': 5.5,
#    'contactTracerCapacityRatio': 0.09,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-17'},
#   {'testPositivityRatio': 0.101,
#    'caseDensity': 5.6,
#    'contactTracerCapacityRatio': 0.09,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-18'},
#   {'testPositivityRatio': 0.099,
#    'caseDensity': 5.6,
#    'contactTracerCapacityRatio': 0.09,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-19'},
#   {'testPositivityRatio': 0.099,
#    'caseDensity': 6.9,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-20'},
#   {'testPositivityRatio': 0.1,
#    'caseDensity': 6.7,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-21'},
#   {'testPositivityRatio': 0.098,
#    'caseDensity': 6.7,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-22'},
#   {'testPositivityRatio': 0.101,
#    'caseDensity': 7.2,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-23'},
#   {'testPositivityRatio': 0.102,
#    'caseDensity': 7.9,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-24'},
#   {'testPositivityRatio': 0.104,
#    'caseDensity': 8.4,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-25'},
#   {'testPositivityRatio': 0.108,
#    'caseDensity': 9.5,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-26'},
#   {'testPositivityRatio': 0.11,
#    'caseDensity': 8.7,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-27'},
#   {'testPositivityRatio': 0.113,
#    'caseDensity': 9.1,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-28'},
#   {'testPositivityRatio': 0.117,
#    'caseDensity': 9.8,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-29'},
#   {'testPositivityRatio': 0.115,
#    'caseDensity': 9.4,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-30'},
#   {'testPositivityRatio': 0.116,
#    'caseDensity': 10.1,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.08,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-05-31'},
#   {'testPositivityRatio': 0.118,
#    'caseDensity': 10.3,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-01'},
#   {'testPositivityRatio': 0.118,
#    'caseDensity': 9.1,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-02'},
#   {'testPositivityRatio': 0.117,
#    'caseDensity': 8.2,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-03'},
#   {'testPositivityRatio': 0.114,
#    'caseDensity': 7.4,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-04'},
#   {'testPositivityRatio': 0.112,
#    'caseDensity': 6.9,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.12,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-05'},
#   {'testPositivityRatio': 0.112,
#    'caseDensity': 7.8,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-06'},
#   {'testPositivityRatio': 0.113,
#    'caseDensity': 7.4,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-07'},
#   {'testPositivityRatio': 0.112,
#    'caseDensity': 7.0,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-08'},
#   {'testPositivityRatio': 0.111,
#    'caseDensity': 7.7,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-09'},
#   {'testPositivityRatio': 0.114,
#    'caseDensity': 9.1,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-10'},
#   {'testPositivityRatio': 0.115,
#    'caseDensity': 11.0,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-11'},
#   {'testPositivityRatio': 0.117,
#    'caseDensity': 12.6,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-12'},
#   {'testPositivityRatio': 0.121,
#    'caseDensity': 13.3,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-13'},
#   {'testPositivityRatio': 0.122,
#    'caseDensity': 14.9,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-14'},
#   {'testPositivityRatio': 0.121,
#    'caseDensity': 15.6,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-15'},
#   {'testPositivityRatio': 0.125,
#    'caseDensity': 16.0,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-16'},
#   {'testPositivityRatio': 0.129,
#    'caseDensity': 15.5,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-17'},
#   {'testPositivityRatio': 0.132,
#    'caseDensity': 15.6,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-18'},
#   {'testPositivityRatio': 0.134,
#    'caseDensity': 15.4,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-19'},
#   {'testPositivityRatio': 0.132,
#    'caseDensity': 14.4,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-20'},
#   {'testPositivityRatio': 0.132,
#    'caseDensity': 12.8,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-21'},
#   {'testPositivityRatio': 0.135,
#    'caseDensity': 12.2,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-22'},
#   {'testPositivityRatio': 0.131,
#    'caseDensity': 12.2,
#    'contactTracerCapacityRatio': 0.05,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-23'},
#   {'testPositivityRatio': 0.127,
#    'caseDensity': 13.8,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-24'},
#   {'testPositivityRatio': 0.127,
#    'caseDensity': 14.6,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-25'},
#   {'testPositivityRatio': 0.127,
#    'caseDensity': 15.1,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-26'},
#   {'testPositivityRatio': 0.127,
#    'caseDensity': 16.1,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-27'},
#   {'testPositivityRatio': 0.129,
#    'caseDensity': 15.8,
#    'contactTracerCapacityRatio': 0.04,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-28'},
#   {'testPositivityRatio': 0.13,
#    'caseDensity': 19.6,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.17,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-29'},
#   {'testPositivityRatio': 0.131,
#    'caseDensity': 20.2,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.17,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-06-30'},
#   {'testPositivityRatio': 0.132,
#    'caseDensity': 20.1,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-01'},
#   {'testPositivityRatio': 0.135,
#    'caseDensity': 20.1,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-02'},
#   {'testPositivityRatio': 0.139,
#    'caseDensity': 22.4,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-03'},
#   {'testPositivityRatio': 0.143,
#    'caseDensity': 22.7,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-04'},
#   {'testPositivityRatio': 0.146,
#    'caseDensity': 24.8,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-05'},
#   {'testPositivityRatio': 0.151,
#    'caseDensity': 22.4,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-06'},
#   {'testPositivityRatio': 0.153,
#    'caseDensity': 22.6,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.18,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-07'},
#   {'testPositivityRatio': 0.16,
#    'caseDensity': 23.3,
#    'contactTracerCapacityRatio': 0.03,
#    'infectionRate': 1.17,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-08'},
#   {'testPositivityRatio': 0.163,
#    'caseDensity': 26.4,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.17,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-09'},
#   {'testPositivityRatio': 0.163,
#    'caseDensity': 25.2,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-10'},
#   {'testPositivityRatio': 0.163,
#    'caseDensity': 26.5,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.16,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-11'},
#   {'testPositivityRatio': 0.162,
#    'caseDensity': 28.1,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.15,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-12'},
#   {'testPositivityRatio': 0.161,
#    'caseDensity': 31.1,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.14,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-13'},
#   {'testPositivityRatio': 0.165,
#    'caseDensity': 33.4,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.13,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-14'},
#   {'testPositivityRatio': 0.163,
#    'caseDensity': 35.3,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.11,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-15'},
#   {'testPositivityRatio': 0.164,
#    'caseDensity': 34.7,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.1,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-16'},
#   {'testPositivityRatio': 0.165,
#    'caseDensity': 36.7,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.09,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-17'},
#   {'testPositivityRatio': 0.168,
#    'caseDensity': 38.7,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.07,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-18'},
#   {'testPositivityRatio': 0.168,
#    'caseDensity': 39.1,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.06,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-19'},
#   {'testPositivityRatio': 0.169,
#    'caseDensity': 38.9,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.04,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-20'},
#   {'testPositivityRatio': 0.171,
#    'caseDensity': 38.2,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.03,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-21'},
#   {'testPositivityRatio': 0.173,
#    'caseDensity': 37.1,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.02,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-22'},
#   {'testPositivityRatio': 0.17,
#    'caseDensity': 38.2,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-23'},
#   {'testPositivityRatio': 0.168,
#    'caseDensity': 37.6,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-24'},
#   {'testPositivityRatio': 0.165,
#    'caseDensity': 37.6,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.98,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-25'},
#   {'testPositivityRatio': 0.163,
#    'caseDensity': 35.8,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.97,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-26'},
#   {'testPositivityRatio': 0.16,
#    'caseDensity': 35.6,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.96,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-27'},
#   {'testPositivityRatio': 0.155,
#    'caseDensity': 35.0,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.95,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-28'},
#   {'testPositivityRatio': 0.152,
#    'caseDensity': 34.9,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.95,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-29'},
#   {'testPositivityRatio': 0.148,
#    'caseDensity': 33.7,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.94,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-30'},
#   {'testPositivityRatio': 0.147,
#    'caseDensity': 34.1,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.93,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-07-31'},
#   {'testPositivityRatio': 0.146,
#    'caseDensity': 32.7,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.92,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-01'},
#   {'testPositivityRatio': 0.144,
#    'caseDensity': 35.4,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.91,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-02'},
#   {'testPositivityRatio': 0.143,
#    'caseDensity': 33.6,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.91,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-03'},
#   {'testPositivityRatio': 0.138,
#    'caseDensity': 33.0,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.9,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-04'},
#   {'testPositivityRatio': 0.133,
#    'caseDensity': 31.7,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-05'},
#   {'testPositivityRatio': 0.128,
#    'caseDensity': 31.6,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-06'},
#   {'testPositivityRatio': 0.125,
#    'caseDensity': 30.8,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.88,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-07'},
#   {'testPositivityRatio': 0.122,
#    'caseDensity': 31.5,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.88,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-08'},
#   {'testPositivityRatio': 0.114,
#    'caseDensity': 28.8,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.87,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-09'},
#   {'testPositivityRatio': 0.113,
#    'caseDensity': 30.2,
#    'contactTracerCapacityRatio': 0.02,
#    'infectionRate': 0.87,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-10'},
#   {'testPositivityRatio': 0.107,
#    'caseDensity': 29.6,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 0.88,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-11'},
#   {'testPositivityRatio': 0.104,
#    'caseDensity': 29.5,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 0.88,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-12'},
#   {'testPositivityRatio': 0.093,
#    'caseDensity': 26.1,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 0.89,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-13'},
#   {'testPositivityRatio': 0.086,
#    'caseDensity': 23.3,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 0.9,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-14'},
#   {'testPositivityRatio': 0.08,
#    'caseDensity': 21.6,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 0.91,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-15'},
#   {'testPositivityRatio': 0.084,
#    'caseDensity': 20.7,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 0.92,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-16'},
#   {'testPositivityRatio': 0.079,
#    'caseDensity': 17.4,
#    'contactTracerCapacityRatio': 0.09,
#    'infectionRate': 0.93,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-17'},
#   {'testPositivityRatio': 0.078,
#    'caseDensity': 19.0,
#    'contactTracerCapacityRatio': 0.09,
#    'infectionRate': 0.95,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-18'},
#   {'testPositivityRatio': 0.076,
#    'caseDensity': 19.5,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 0.96,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-19'},
#   {'testPositivityRatio': 0.08,
#    'caseDensity': 20.1,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 0.98,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-20'},
#   {'testPositivityRatio': 0.08,
#    'caseDensity': 21.3,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-21'},
#   {'testPositivityRatio': 0.082,
#    'caseDensity': 20.3,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-22'},
#   {'testPositivityRatio': 0.08,
#    'caseDensity': 19.3,
#    'contactTracerCapacityRatio': 0.09,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-23'},
#   {'testPositivityRatio': 0.082,
#    'caseDensity': 22.5,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-24'},
#   {'testPositivityRatio': 0.084,
#    'caseDensity': 20.0,
#    'contactTracerCapacityRatio': 0.08,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-25'},
#   {'testPositivityRatio': 0.085,
#    'caseDensity': 22.7,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-26'},
#   {'testPositivityRatio': 0.087,
#    'caseDensity': 25.0,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.01,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-27'},
#   {'testPositivityRatio': 0.104,
#    'caseDensity': 24.9,
#    'contactTracerCapacityRatio': 0.07,
#    'infectionRate': 1.0,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-28'},
#   {'testPositivityRatio': 0.105,
#    'caseDensity': 27.3,
#    'contactTracerCapacityRatio': 0.06,
#    'infectionRate': 0.99,
#    'infectionRateCI90': 0.1,
#    'icuHeadroomRatio': None,
#    'icuCapacityRatio': None,
#    'date': '2020-08-29'},
#   {'testPositivityRatio': 0.107,
#    'caseDensity': 29.6,
# ...
#   {'overall': 2, 'date': '2020-05-15'},
#   {'overall': 2, 'date': '2020-05-16'},
#   {'overall': 2, 'date': '2020-05-17'},
#   {'overall': 2, 'date': '2020-05-18'},
#   {'overall': 2, 'date': '2020-05-19'},
#   {'overall': 2, 'date': '2020-05-20'},
#   {'overall': 2, 'date': '2020-05-21'},
#   {'overall': 2, 'date': '2020-05-22'},
#   {'overall': 2, 'date': '2020-05-23'},
#   {'overall': 2, 'date': '2020-05-24'},
#   {'overall': 2, 'date': '2020-05-25'},
#   {'overall': 2, 'date': '2020-05-26'},
#   {'overall': 2, 'date': '2020-05-27'},
#   {'overall': 2, 'date': '2020-05-28'},
.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 10 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   testPositivityRatio         448 non-null    float64
#  1   caseDensity                 470 non-null    float64
#  2   contactTracerCapacityRatio  400 non-null    float64
#  3   infectionRate               462 non-null    float64
#  4   infectionRateCI90           462 non-null    float64
#  5   icuHeadroomRatio            285 non-null    float64
#  6   icuCapacityRatio            285 non-null    float64
#  7   date                        474 non-null    object
#  8   vaccinationsInitiatedRatio  148 non-null    float64
#  9   vaccinationsCompletedRatio  148 non-null    float64
# dtypes: float64(9), object(1)
# memory usage: 37.2+ KB

# %%
type(metric)
# Out:
# pandas.core.frame.DataFrame

# %%
if state_summary['metricsTimeseries']:
    metrics=pd.DataFrame(metric[['date','testPositivityRatio','caseDensity','contactTracerCapacityRatio','infectionRate','infectionRateCI90','icuHeadroomRatio','icuCapacityRatio']])

# %%
metrics['month-year'] = metrics['date'].str.slice(0,7)

# %%
metrics.groupby('month-year').mean()
# Out:
#             testPositivityRatio  caseDensity  contactTracerCapacityRatio  \
# month-year
# 2020-03                0.050571     0.448387                         NaN
# 2020-04                0.041700     2.165517                         NaN
# 2020-05                0.032452     2.003226                    0.604762
# 2020-06                0.024467     2.956667                    0.783667
# 2020-07                0.034065     6.641935                    0.269032
# 2020-08                0.030516     6.773333                    0.261667
# 2020-09                0.029467    10.776667                    0.200000
# 2020-10                0.061548    36.590323                    0.052903
# 2020-11                0.124767   110.168966                    0.016207
# 2020-12                0.096355    67.038710                    0.029355
# 2021-01                0.069419    43.900000                    0.042903
# 2021-02                0.038714    16.589286                    0.111786
# 2021-03                0.033581    10.874194                    0.161613
# 2021-04                0.040000    10.290000                    0.167667
# 2021-05                0.045226    12.064516                    0.144194
# 2021-06                0.046200    12.012500                    0.145000
#
#             infectionRate  infectionRateCI90  icuHeadroomRatio  \
# month-year
# 2020-03          1.290500           0.662500               NaN
# 2020-04          0.932000           0.424333               NaN
# 2020-05          0.890323           0.430323               NaN
# 2020-06          1.124667           0.365667               NaN
# 2020-07          1.063548           0.226774               NaN
# 2020-08          0.974839           0.213871               NaN
# 2020-09          1.194000           0.184667          0.058667
# 2020-10          1.188065           0.105161          0.187097
# 2020-11          1.075667           0.100000          0.356000
# 2020-12          0.863871           0.100000          0.320323
# 2021-01          0.905161           0.102258          0.164194
# 2021-02          0.880357           0.135714          0.077857
# 2021-03          0.962581           0.166452          0.064194
# 2021-04          1.010333           0.175333          0.057333
# 2021-05          1.014516           0.161290          0.107419
# 2021-06          0.967500           0.186250          0.129167
#
#             icuCapacityRatio
# month-year
# 2020-03                  NaN
# 2020-04                  NaN
# 2020-05                  NaN
# 2020-06                  NaN
# 2020-07                  NaN
# 2020-08                  NaN
# 2020-09             0.356667
# 2020-10             0.423871
# 2020-11             0.483667
# 2020-12             0.457097
# 2021-01             0.370645
# 2021-02             0.337143
# 2021-03             0.305484
# 2021-04             0.316000
# 2021-05             0.337097
# 2021-06             0.379167

# %%
for i in state_json:
     actual=pd.DataFrame(i['actualsTimeseries'])     
actual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 474 entries, 0 to 473
# Data columns (total 16 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   cases                              463 non-null    float64
#  1   deaths                             463 non-null    float64
#  2   positiveTests                      449 non-null    float64
#  3   negativeTests                      449 non-null    float64
#  4   contactTracers                     403 non-null    float64
#  5   hospitalBeds                       474 non-null    object
#  6   icuBeds                            474 non-null    object
#  7   newCases                           460 non-null    float64
#  8   newDeaths                          463 non-null    float64
#  9   vaccinesAdministeredDemographics   0 non-null      object
#  10  vaccinationsInitiatedDemographics  0 non-null      object
#  11  date                               474 non-null    object
#  12  vaccinesDistributed                148 non-null    float64
#  13  vaccinationsInitiated              148 non-null    float64
#  14  vaccinationsCompleted              148 non-null    float64
#  15  vaccinesAdministered               148 non-null    float64
# dtypes: float64(11), object(5)
# memory usage: 59.4+ KB

# %%
if state_summary['actualsTimeseries']:
    actuals=pd.DataFrame(actual[['date','cases','deaths','positiveTests','negativeTests','newCases','newDeaths','vaccinesDistributed','vaccinationsInitiated','vaccinationsCompleted','vaccinesAdministered']])

# %%
actuals
# Out:
#            date    cases  deaths  positiveTests  negativeTests  newCases  \
# 0    2020-03-01      NaN     NaN            NaN            NaN       NaN
# 1    2020-03-02      NaN     NaN            NaN            NaN       NaN
# 2    2020-03-03      NaN     NaN            NaN            NaN       NaN
# 3    2020-03-04      NaN     NaN            NaN            NaN       NaN
# 4    2020-03-05      NaN     NaN            NaN            NaN       NaN
# ..          ...      ...     ...            ...            ...       ...
# 469  2021-06-13  61115.0   725.0        52992.0       750547.0       0.0
# 470  2021-06-14  61235.0   725.0        53028.0       750944.0     120.0
# 471  2021-06-15  61303.0   734.0        53038.0       751012.0      68.0
# 472  2021-06-16  61359.0   734.0            NaN            NaN      56.0
# 473  2021-06-17      NaN     NaN            NaN            NaN       NaN
#
#      newDeaths  vaccinesDistributed  vaccinationsInitiated  \
# 0          NaN                  NaN                    NaN
# 1          NaN                  NaN                    NaN
# 2          NaN                  NaN                    NaN
# 3          NaN                  NaN                    NaN
# 4          NaN                  NaN                    NaN
# ..         ...                  ...                    ...
# 469        0.0             510585.0               220814.0
# 470        0.0             510585.0               220895.0
# 471        9.0             510585.0               221700.0
# 472        0.0             510585.0               221754.0
# 473        NaN                  NaN                    NaN
#
#      vaccinationsCompleted  vaccinesAdministered
# 0                      NaN                   NaN
# 1                      NaN                   NaN
# 2                      NaN                   NaN
# 3                      NaN                   NaN
# 4                      NaN                   NaN
# ..                     ...                   ...
# 469               191066.0              408103.0
# 470               191169.0              408189.0
# 471               192334.0              410113.0
# 472               192396.0              410138.0
# 473                    NaN                   NaN
#
# [474 rows x 11 columns]

# %%
actuals['month-year'] = actual['date'].str.slice(0,7)

# %%
actual_gb = actuals.groupby('month-year').mean().reset_index()
actual_gb['month-year'] = pd.to_datetime(actual_gb['month-year'])
ggplot(actual_gb)+ geom_line(aes(x='month-year', y='vaccinesDistributed'))
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 10 rows containing missing values.
# <ggplot: (329639661)>

# %%
def get_metrics():
    state_json = result.json()
    for state_summary in state_json:
        metrics=pd.DataFrame(state_summary['metricsTimeseries']) 
        metrics['month-year'] = metrics['date'].str.slice(0,7)
        state_chose = state_summary['state']
#         print(state_summary['state'])
        metrics_per_month = metrics.groupby('month-year').mean()
#        print(metrics.groupby('month-year').mean())

# %%
state_json = result.json()
for state_summary in state_json:
    metrics=pd.DataFrame(state_summary['metricsTimeseries']) 
    metrics['month-year'] = metrics['date'].str.slice(0,7)
    state_chose = state_summary['state']
#   print(state_summary['state'])
    metrics_per_month = metrics.groupby('month-year').mean()
#   print(metrics.groupby('month-year').mean())

# %%
metrics_per_month
# Out:
#             testPositivityRatio  caseDensity  contactTracerCapacityRatio  \
# month-year
# 2020-03                0.050571     0.448387                         NaN
# 2020-04                0.041700     2.165517                         NaN
# 2020-05                0.032452     2.003226                    0.604762
# 2020-06                0.024467     2.956667                    0.783667
# 2020-07                0.034065     6.641935                    0.269032
# 2020-08                0.030516     6.773333                    0.261667
# 2020-09                0.029467    10.776667                    0.200000
# 2020-10                0.061548    36.590323                    0.052903
# 2020-11                0.124767   110.168966                    0.016207
# 2020-12                0.096355    67.038710                    0.029355
# 2021-01                0.069419    43.900000                    0.042903
# 2021-02                0.038714    16.589286                    0.111786
# 2021-03                0.033581    10.874194                    0.161613
# 2021-04                0.040000    10.290000                    0.167667
# 2021-05                0.045226    12.064516                    0.144194
# 2021-06                0.046200    12.012500                    0.145000
#
#             infectionRate  infectionRateCI90  icuHeadroomRatio  \
# month-year
# 2020-03          1.290500           0.662500               NaN
# 2020-04          0.932000           0.424333               NaN
# 2020-05          0.890323           0.430323               NaN
# 2020-06          1.124667           0.365667               NaN
# 2020-07          1.063548           0.226774               NaN
# 2020-08          0.974839           0.213871               NaN
# 2020-09          1.194000           0.184667          0.058667
# 2020-10          1.188065           0.105161          0.187097
# 2020-11          1.075667           0.100000          0.356000
# 2020-12          0.863871           0.100000          0.320323
# 2021-01          0.905161           0.102258          0.164194
# 2021-02          0.880357           0.135714          0.077857
# 2021-03          0.962581           0.166452          0.064194
# 2021-04          1.010333           0.175333          0.057333
# 2021-05          1.014516           0.161290          0.107419
# 2021-06          0.967500           0.186250          0.129167
#
#             icuCapacityRatio  vaccinationsInitiatedRatio  \
# month-year
# 2020-03                  NaN                         NaN
# 2020-04                  NaN                         NaN
# 2020-05                  NaN                         NaN
# 2020-06                  NaN                         NaN
# 2020-07                  NaN                         NaN
# 2020-08                  NaN                         NaN
# 2020-09             0.356667                         NaN
# 2020-10             0.423871                         NaN
# 2020-11             0.483667                         NaN
# 2020-12             0.457097                         NaN
# 2021-01             0.370645                    0.056800
# 2021-02             0.337143                    0.125654
# 2021-03             0.305484                    0.221516
# 2021-04             0.316000                    0.313567
# 2021-05             0.337097                    0.354333
# 2021-06             0.379167                    0.377437
#
#             vaccinationsCompletedRatio
# month-year
# 2020-03                            NaN
# 2020-04                            NaN
# 2020-05                            NaN
# 2020-06                            NaN
# 2020-07                            NaN
# 2020-08                            NaN
# 2020-09                            NaN
# 2020-10                            NaN
# 2020-11                            NaN
# 2020-12                            NaN
# 2021-01                       0.008467
# 2021-02                       0.049231
# 2021-03                       0.137968
# 2021-04                       0.234400
# 2021-05                       0.301133
# 2021-06                       0.325125

# %%
def get_actuals():
    state_json = result.json()
    for state_summary in state_json:
        actuals=pd.DataFrame(state_summary['actualsTimeseries']) 
        actuals['month-year'] = actuals['date'].str.slice(0,7)
        print(state_summary['state'])
        print(actuals.groupby('month-year').mean())

# %%
get_actuals()
# Out:
# AK
#                    cases      deaths  positiveTests  negativeTests  \
# month-year
# 2020-03        42.550000    0.400000      67.952381   1.949258e+03
# 2020-04       274.366667    5.766667     359.833333   1.452803e+04
# 2020-05       395.354839    7.838710     516.774194   4.093090e+04
# 2020-06       766.766667    9.700000    1026.000000   9.631263e+04
# 2020-07      2181.709677   16.000000    3393.516129   2.120073e+05
# 2020-08      4995.838710   27.193548    8355.645161   3.733751e+05
# 2020-09      7341.100000   42.166667   13021.000000   5.387370e+05
# 2020-10     11847.129032   60.967742   23164.193548   7.111801e+05
# 2020-11     24034.533333   93.400000   50985.400000   9.469694e+05
# 2020-12     41250.064516  165.677419   77845.774194   1.215328e+06
# 2021-01     51033.354839  227.935484   89699.225806   1.440064e+06
# 2021-02     56170.250000  273.000000   96692.250000   1.653724e+06
# 2021-03     60266.354839  294.290323  101469.161290   1.851332e+06
# 2021-04     65182.600000  311.233333  107287.666667   2.057547e+06
# 2021-05     68863.548387  341.967742  111389.322581   2.234577e+06
# 2021-06     69969.875000  353.500000  112638.214286   2.340770e+06
#
#             contactTracers    newCases  newDeaths  vaccinesDistributed  \
# month-year
# 2020-03                NaN    6.650000   0.100000                  NaN
# 2020-04                NaN    7.333333   0.166667                  NaN
# 2020-05         143.095238    3.741935   0.032258                  NaN
# 2020-06         132.033333   22.100000   0.133333                  NaN
# 2020-07         155.451613   82.032258   0.290323                  NaN
# 2020-08         211.161290   80.166667   0.419355                  NaN
# 2020-09         234.000000   87.733333   0.600000                  NaN
# 2020-10         234.000000  243.225806   0.806452                  NaN
# 2020-11         234.000000  538.666667   1.266667                  NaN
# 2020-12         234.903226  462.354839   2.709677                  NaN
# 2021-01         235.000000  233.709677   1.774194        164590.000000
# 2021-02         235.000000  137.892857   0.928571        276030.961538
# 2021-03         235.000000  152.032258   0.677419        486942.096774
# 2021-04         235.000000  167.966667   1.033333        716744.000000
# 2021-05         235.000000   65.451613   0.709677        790333.000000
# 2021-06         235.000000   34.750000   0.250000        816356.875000
#
#             vaccinationsInitiated  vaccinationsCompleted  vaccinesAdministered
# month-year
# 2020-03                       NaN                    NaN                   NaN
# 2020-04                       NaN                    NaN                   NaN
# 2020-05                       NaN                    NaN                   NaN
# 2020-06                       NaN                    NaN                   NaN
# 2020-07                       NaN                    NaN                   NaN
# 2020-08                       NaN                    NaN                   NaN
# 2021-05          50.000000   64.580645   0.387097        494532.666667
# 2021-06          50.000000   75.937500   0.937500        509056.250000
#
#             vaccinationsInitiated  vaccinationsCompleted  vaccinesAdministered
# month-year
# 2020-03                       NaN                    NaN                   NaN
# 2020-04                       NaN                    NaN                   NaN
# 2020-05                       NaN                    NaN                   NaN
# 2020-06                       NaN                    NaN                   NaN
# 2020-07                       NaN                    NaN                   NaN
# 2020-08                       NaN                    NaN                   NaN
# 2020-09                       NaN                    NaN                   NaN
# 2020-10                       NaN                    NaN                   NaN
# 2020-11                       NaN                    NaN                   NaN
# 2020-12                       NaN                    NaN                   NaN
# 2021-01              32758.533333            4991.533333          37787.000000
# 2021-02              72687.538462           28453.615385         102122.653846
# 2021-03             128188.580645           79841.419355         209713.161290
# 2021-04             181523.233333          135638.933333         315858.666667
# 2021-05             205095.433333          174295.766667         377688.866667
# 2021-06             218438.625000          188225.875000         403184.750000

# %%
state_json = result.json()
for state_summary in state_json:
    actuals=pd.DataFrame(state_summary['actualsTimeseries']) 
    actuals['month-year'] = actuals['date'].str.slice(0,7)
#     actual_state = state_summary['state']
#     gb_actual = actuals.groupby('month-year').mean()
actuals
# Out:
#        cases  deaths  positiveTests  negativeTests  contactTracers  \
# 0        NaN     NaN            NaN            NaN             NaN
# 1        NaN     NaN            NaN            NaN             NaN
# 2        NaN     NaN            NaN            NaN             NaN
# 3        NaN     NaN            NaN            NaN             NaN
# 4        NaN     NaN            NaN            NaN             NaN
# ..       ...     ...            ...            ...             ...
# 469  61115.0   725.0        52992.0       750547.0            50.0
# 470  61235.0   725.0        53028.0       750944.0            50.0
# 471  61303.0   734.0        53038.0       751012.0            50.0
# 472  61359.0   734.0            NaN            NaN            50.0
# 473      NaN     NaN            NaN            NaN            50.0
#
#                                           hospitalBeds  \
# 0    {'capacity': None, 'currentUsageTotal': None, ...
# 1    {'capacity': None, 'currentUsageTotal': None, ...
# 2    {'capacity': None, 'currentUsageTotal': None, ...
# 3    {'capacity': None, 'currentUsageTotal': None, ...
# 4    {'capacity': None, 'currentUsageTotal': None, ...
# ..                                                 ...
# 469  {'capacity': None, 'currentUsageTotal': None, ...
# 470  {'capacity': None, 'currentUsageTotal': None, ...
# 471  {'capacity': None, 'currentUsageTotal': None, ...
# 472  {'capacity': None, 'currentUsageTotal': None, ...
# 473  {'capacity': None, 'currentUsageTotal': None, ...
#
#                                                icuBeds  newCases  newDeaths  \
# 0    {'capacity': None, 'currentUsageTotal': None, ...       NaN        NaN
# 1    {'capacity': None, 'currentUsageTotal': None, ...       NaN        NaN
# 2    {'capacity': None, 'currentUsageTotal': None, ...       NaN        NaN
# 3    {'capacity': None, 'currentUsageTotal': None, ...       NaN        NaN
# 4    {'capacity': None, 'currentUsageTotal': None, ...       NaN        NaN
# ..                                                 ...       ...        ...
# 469  {'capacity': None, 'currentUsageTotal': None, ...       0.0        0.0
# 470  {'capacity': None, 'currentUsageTotal': None, ...     120.0        0.0
# 471  {'capacity': None, 'currentUsageTotal': None, ...      68.0        9.0
# 472  {'capacity': None, 'currentUsageTotal': None, ...      56.0        0.0
# 473  {'capacity': None, 'currentUsageTotal': None, ...       NaN        NaN
#
#     vaccinesAdministeredDemographics vaccinationsInitiatedDemographics  \
# 0                               None                              None
# 1                               None                              None
# 2                               None                              None
# 3                               None                              None
# 4                               None                              None
# ..                               ...                               ...
# 469                             None                              None
# 470                             None                              None
# 471                             None                              None
# 472                             None                              None
# 473                             None                              None
#
#            date  vaccinesDistributed  vaccinationsInitiated  \
# 0    2020-03-01                  NaN                    NaN
# 1    2020-03-02                  NaN                    NaN
# 2    2020-03-03                  NaN                    NaN
# 3    2020-03-04                  NaN                    NaN
# 4    2020-03-05                  NaN                    NaN
# ..          ...                  ...                    ...
# 469  2021-06-13             510585.0               220814.0
# 470  2021-06-14             510585.0               220895.0
# 471  2021-06-15             510585.0               221700.0
# 472  2021-06-16             510585.0               221754.0
# 473  2021-06-17                  NaN                    NaN
#
#      vaccinationsCompleted  vaccinesAdministered month-year
# 0                      NaN                   NaN    2020-03
# 1                      NaN                   NaN    2020-03
# 2                      NaN                   NaN    2020-03
# 3                      NaN                   NaN    2020-03
# 4                      NaN                   NaN    2020-03
# ..                     ...                   ...        ...
# 469               191066.0              408103.0    2021-06
# 470               191169.0              408189.0    2021-06
# 471               192334.0              410113.0    2021-06
# 472               192396.0              410138.0    2021-06
# 473                    NaN                   NaN    2021-06
#
# [474 rows x 17 columns]

# %%
state_json = result.json()
for state_summary in state_json:
    actuals=pd.DataFrame(state_summary['actualsTimeseries']) 
    actuals['month-year'] = actuals['date'].str.slice(0,7)
    actual_state = state_summary['state']
    gb_actual = actuals.groupby('month-year').mean()

# %%
new_gb = gb_actual.reset_index()
new_gb['month-year']= pd.to_datetime(new_gb['month-year'])

# %%
new_gb
# Out:
#    month-year         cases      deaths  positiveTests  negativeTests  \
# 0  2020-03-01     36.952381    0.000000       1.000000       0.000000
# 1  2020-04-01    366.233333    2.733333     253.033333    5388.366667
# 2  2020-05-01    734.838710    9.677419     941.419355   22817.225806
# 3  2020-06-01   1123.800000   18.500000    1651.633333   47839.333333
# 4  2020-07-01   2063.870968   22.903226    2512.193548   77030.838710
# 5  2020-08-01   3301.806452   31.967742    3585.741935  107169.967742
# 6  2020-09-01   4668.533333   45.833333    4812.200000  154603.166667
# 7  2020-10-01   9007.677419   62.129032    8436.548387  223661.290323
# 8  2020-11-01  23276.700000  152.100000   21856.100000  338011.233333
# 9  2020-12-01  39976.129032  330.064516   36335.516129  443289.612903
# 10 2021-01-01  48686.645161  525.451613   42859.548387  527488.935484
# 11 2021-02-01  53260.500000  648.321429   46506.107143  590905.535714
# 12 2021-03-01  55375.516129  690.096774   48310.774194  643172.483871
# 13 2021-04-01  57205.066667  703.033333   50154.100000  688463.233333
# 14 2021-05-01  59201.290323  712.870968   51707.935484  723702.000000
# 15 2021-06-01  60876.312500  723.937500   52764.266667  745536.533333
#
#     contactTracers    newCases  newDeaths  vaccinesDistributed  \
# 0              NaN    5.761905   0.000000                  NaN
# 1              NaN   12.586207   0.233333                  NaN
# 2        34.761905   11.096774   0.290323                  NaN
# 3        50.000000   19.466667   0.133333                  NaN
# 4        50.000000   39.967742   0.193548                  NaN
# 5        50.000000   37.466667   0.354839                  NaN
# 6        50.000000   70.200000   0.433333                  NaN
# 7        50.000000  237.096774   1.193548                  NaN
# 8        50.000000  655.551724   4.266667                  NaN
# 9        50.000000  358.193548   7.193548                  NaN
# 10       50.000000  242.032258   5.096774         72191.666667
# 11       50.000000   88.642857   2.678571        133798.653846
# 12       50.000000   61.806452   0.935484        287594.032258
# 13       50.000000   61.066667   0.233333        452299.666667
# 14       50.000000   64.580645   0.387097        494532.666667
# 15       50.000000   75.937500   0.937500        509056.250000
#
#     vaccinationsInitiated  vaccinationsCompleted  vaccinesAdministered
# 0                     NaN                    NaN                   NaN
# 1                     NaN                    NaN                   NaN
# 2                     NaN                    NaN                   NaN
# 3                     NaN                    NaN                   NaN
# 4                     NaN                    NaN                   NaN
# 5                     NaN                    NaN                   NaN
# 6                     NaN                    NaN                   NaN
# 7                     NaN                    NaN                   NaN
# 8                     NaN                    NaN                   NaN
# 9                     NaN                    NaN                   NaN
# 10           32758.533333            4991.533333          37787.000000
# 11           72687.538462           28453.615385         102122.653846
# 12          128188.580645           79841.419355         209713.161290
# 13          181523.233333          135638.933333         315858.666667
# 14          205095.433333          174295.766667         377688.866667
# 15          218438.625000          188225.875000         403184.750000

# %%
new_gb.dtypes
# Out:
# month-year               datetime64[ns]
# cases                           float64
# deaths                          float64
# positiveTests                   float64
# negativeTests                   float64
# contactTracers                  float64
# newCases                        float64
# newDeaths                       float64
# vaccinesDistributed             float64
# vaccinationsInitiated           float64
# vaccinationsCompleted           float64
# vaccinesAdministered            float64
# dtype: object

# %%
ggplot(new_gb)+ geom_line(aes(x='month-year', y='vaccinesDistributed'))
# Out:
# /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages/plotnine/geoms/geom_path.py:75: PlotnineWarning: geom_path: Removed 10 rows containing missing values.
# <ggplot: (327371505)>

# %%
ggplot(new_gb) + geom_line(aes(x="month-year", y="cases"))
# Out:
# <ggplot: (329752213)>

# %%
fig = px.line(new_gb, x='month-year', y="cases")
fig.show()
fig1 = px.line(new_gb, x='month-year', y="deaths")
fig1.show()
# Out:
# <div>                            <div id="20c83e3a-29ed-4d22-9ac6-1cf52ce27daf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20c83e3a-29ed-4d22-9ac6-1cf52ce27daf")) {                    Plotly.newPlot(                        "20c83e3a-29ed-4d22-9ac6-1cf52ce27daf",                        [{"hovertemplate": "month-year=%{x}<br>cases=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-08-01T00:00:00", "2020-09-01T00:00:00", "2020-10-01T00:00:00", "2020-11-01T00:00:00", "2020-12-01T00:00:00", "2021-01-01T00:00:00", "2021-02-01T00:00:00", "2021-03-01T00:00:00", "2021-04-01T00:00:00", "2021-05-01T00:00:00", "2021-06-01T00:00:00"], "xaxis": "x", "y": [36.95238095238095, 366.23333333333335, 734.8387096774194, 1123.8, 2063.8709677419356, 3301.8064516129034, 4668.533333333334, 9007.677419354839, 23276.7, 39976.12903225807, 48686.645161290326, 53260.5, 55375.51612903226, 57205.066666666666, 59201.290322580644, 60876.3125], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewi ...
# <div>                            <div id="8438d22b-0bc2-4f7e-b48c-e4be53d2891f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8438d22b-0bc2-4f7e-b48c-e4be53d2891f")) {                    Plotly.newPlot(                        "8438d22b-0bc2-4f7e-b48c-e4be53d2891f",                        [{"hovertemplate": "month-year=%{x}<br>deaths=%{y}<extra></extra>", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "orientation": "v", "showlegend": false, "type": "scatter", "x": ["2020-03-01T00:00:00", "2020-04-01T00:00:00", "2020-05-01T00:00:00", "2020-06-01T00:00:00", "2020-07-01T00:00:00", "2020-08-01T00:00:00", "2020-09-01T00:00:00", "2020-10-01T00:00:00", "2020-11-01T00:00:00", "2020-12-01T00:00:00", "2021-01-01T00:00:00", "2021-02-01T00:00:00", "2021-03-01T00:00:00", "2021-04-01T00:00:00", "2021-05-01T00:00:00", "2021-06-01T00:00:00"], "xaxis": "x", "y": [0.0, 2.7333333333333334, 9.67741935483871, 18.5, 22.903225806451612, 31.967741935483872, 45.833333333333336, 62.12903225806452, 152.1, 330.06451612903226, 525.4516129032259, 648.3214285714286, 690.0967741935484, 703.0333333333333, 712.8709677419355, 723.9375], "yaxis": "y"}],                        {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "t ...

# %%
all_states_df = pd.read_csv("states.timeseries.csv")

all_states_df
# Out:
#              date country state  county  fips  lat  long          locationId  \
# 0      2020-03-01      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 1      2020-03-02      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 2      2020-03-03      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 3      2020-03-04      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# 4      2020-03-05      US    AK     NaN     2  NaN   NaN  iso1:us#iso2:us-ak
# ...           ...     ...   ...     ...   ...  ...   ...                 ...
# 25292  2021-06-11      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25293  2021-06-12      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25294  2021-06-13      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25295  2021-06-14      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
# 25296  2021-06-15      US    WY     NaN    56  NaN   NaN  iso1:us#iso2:us-wy
#
#        actuals.cases  actuals.deaths  ...  metrics.infectionRate  \
# 0                NaN             NaN  ...                    NaN
# 1                NaN             NaN  ...                    NaN
# 2                NaN             NaN  ...                    NaN
# 3                NaN             NaN  ...                    NaN
# 4                NaN             NaN  ...                    NaN
# ...              ...             ...  ...                    ...
# 25292        61115.0           725.0  ...                   0.95
# 25293        61115.0           725.0  ...                   0.95
# 25294        61115.0           725.0  ...                   0.94
# 25295        61235.0           725.0  ...                   0.94
# 25296            NaN             NaN  ...                    NaN
#
#        metrics.infectionRateCI90  metrics.icuHeadroomRatio  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 25292                       0.19                      0.14
# 25293                       0.20                      0.15
# 25294                       0.21                       NaN
# 25295                       0.22                       NaN
# 25296                        NaN                       NaN
#
#        metrics.icuHeadroomDetails  metrics.icuCapacityRatio  \
# 0                             NaN                       NaN
# 1                             NaN                       NaN
# 2                             NaN                       NaN
# 3                             NaN                       NaN
# 4                             NaN                       NaN
# ...                           ...                       ...
# 25292                         NaN                      0.36
# 25293                         NaN                      0.34
# 25294                         NaN                       NaN
# 25295                         NaN                       NaN
# 25296                         NaN                       NaN
#
#        riskLevels.overall  metrics.vaccinationsInitiatedRatio  \
# 0                       0                                 NaN
# 1                       0                                 NaN
# 2                       0                                 NaN
# 3                       0                                 NaN
# 4                       0                                 NaN
# ...                   ...                                 ...
# 25292                   2                               0.379
# 25293                   2                               0.381
# 25294                   2                               0.382
# 25295                   2                               0.382
# 25296                   2                                 NaN
#
#        metrics.vaccinationsCompletedRatio  actuals.newDeaths  \
# 0                                     NaN                NaN
# 1                                     NaN                NaN
# 2                                     NaN                NaN
# 3                                     NaN                NaN
# 4                                     NaN                NaN
# ...                                   ...                ...
# 25292                               0.326                0.0
# 25293                               0.329                0.0
# 25294                               0.330                0.0
# 25295                               0.330                0.0
# 25296                                 NaN                NaN
#
#        actuals.vaccinesAdministered
# 0                               NaN
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 25292                      404335.0
# 25293                      406642.0
# 25294                      408103.0
# 25295                      408189.0
# 25296                           NaN
#
# [25297 rows x 39 columns]
