# %%
import pandas as pd
import numpy as np
from plotnine import ggplot, aes, geom_line
import plotly.express as px

# %%
all_statesdf = pd.read_csv("https://api.covidactnow.org/v2/states.timeseries.csv?apiKey=1540d77cf9a0422b88a2d90e989bbd23")

# %%
all_statesdf.columns
# Out:
# Index(['date', 'country', 'state', 'county', 'fips', 'lat', 'long',
#        'locationId', 'actuals.cases', 'actuals.deaths',
#        'actuals.positiveTests', 'actuals.negativeTests',
#        'actuals.contactTracers', 'actuals.hospitalBeds.capacity',
#        'actuals.hospitalBeds.currentUsageTotal',
#        'actuals.hospitalBeds.currentUsageCovid',
#        'actuals.hospitalBeds.typicalUsageRate', 'actuals.icuBeds.capacity',
#        'actuals.icuBeds.currentUsageTotal',
#        'actuals.icuBeds.currentUsageCovid', 'actuals.icuBeds.typicalUsageRate',
#        'actuals.newCases', 'actuals.vaccinesDistributed',
#        'actuals.vaccinationsInitiated', 'actuals.vaccinationsCompleted',
#        'metrics.testPositivityRatio', 'metrics.testPositivityRatioDetails',
#        'metrics.caseDensity', 'metrics.contactTracerCapacityRatio',
#        'metrics.infectionRate', 'metrics.infectionRateCI90',
#        'metrics.icuHeadroomRatio', 'metrics.icuHeadroomDetails',
# ...

# %%
new_df = all_statesdf[["date","state","actuals.hospitalBeds.capacity","actuals.newCases",'actuals.newDeaths',"actuals.vaccinesDistributed","actuals.vaccinationsInitiated","actuals.vaccinationsCompleted",'metrics.vaccinationsInitiatedRatio',
       'metrics.vaccinationsCompletedRatio']].reset_index()

# %%
new_df['date'] = pd.to_datetime(new_df["date"])
# hello = new_df.reset_index()

# %%
new_df2 = new_df.pivot(index="date",columns="state")
new_df2['metrics.vaccinationsCompletedRatio']
actualsnewCases = new_df2['metrics.vaccinationsCompletedRatio'].reset_index()
actualsnewCases
# x = actualsnewCases[["date","AK"]].reset_index()
# Out:
# state       date     AK     AL     AR     AZ     CA     CO     CT     DC  \
# 0     2020-01-14    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 1     2020-01-15    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 2     2020-01-16    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 3     2020-01-17    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# 4     2020-01-18    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ..           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 527   2021-06-24  0.420  0.321  0.336  0.394  0.486  0.507  0.593  0.510
# 528   2021-06-25  0.421  0.321  0.337  0.395  0.488  0.508  0.595  0.514
# 529   2021-06-26  0.424  0.322  0.338  0.396  0.490  0.511  0.597  0.515
# 530   2021-06-27  0.426  0.323  0.339  0.398  0.494  0.514  0.600  0.518
# 531   2021-06-28    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
#
# state     DE  ...     SD     TN     TX     UT     VA     VT     WA     WI  \
# ...

# %%
#ggplot(new_df)+ geom_line(aes(x='date', y='actuals.newCases'))

fig = px.line(actualsnewCases, x="date", y="AK")

# %%
fig.show()

# %%
fig1 = px.line(actualsnewCases, x='date', y =A)
fig1.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-4cf051c010f9> in <module>
# ----> 1 fig1 = px.line(actualsnewCases, x='date', y =A)
#       2 fig1.show()
#
# NameError: name 'A' is not defined

# %%
df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/finance-charts-apple.csv')
df.info()
